# %%
import json
import requests
from config import api_key
from pprint import pprint

url = "https://api.nytimes.com/svc/books/v3/lists/best-sellers/history.json"
#isbn = "9780399169274"

# %%
query_url = f"https://api.nytimes.com/svc/books/v3/lists/best-sellers/history.json?api-key={api_key}&isbn={isbn}"

# %%
response = requests.get(query_url).json()
#response
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2022 The New York Times Company.  All Rights Reserved.',
#  'num_results': 0,
#  'results': []}

# %%
isbn_list = ['9780316015844', '9780439023528', '9781338596700', '9780525559474']
response_list = []

for isbn in isbn_list:
    response = requests.get(f"https://api.nytimes.com/svc/books/v3/lists/best-sellers/history.json?api-key={api_key}&isbn={isbn}").json()
    response_list.append(response)   
    pprint(response)
# Out:
# {'copyright': 'Copyright (c) 2022 The New York Times Company.  All Rights '
#               'Reserved.',
#  'num_results': 1,
#  'results': [{'age_group': '',
#               'author': 'Stephenie Meyer',
#               'contributor': 'by Stephenie Meyer',
#               'contributor_note': '',
#               'description': 'Vampires and werewolves and their intrigues in '
#                              'high school.',
#               'isbns': [{'isbn10': '0316067938', 'isbn13': '9780316067935'},
#                         {'isbn10': '0316015849', 'isbn13': '9780316015844'},
#                         {'isbn10': '0316024961', 'isbn13': '9780316024969'},
#                         {'isbn10': '031612558X', 'isbn13': '9780316125581'},
#                         {'isbn10': '0316027650', 'isbn13': '9780316027656'},
#                         {'isbn10': '031606792X', 'isbn13': '9780316067928'},
#                         {'isbn10': '031608736X', 'isbn13': '9780316087360'},
# ...

# %%
#response = requests.get(f"https://api.nytimes.com/svc/books/v3/lists/best-sellers/history.json?api-key={api_key}&isbn=9780525559474").json()
#response
