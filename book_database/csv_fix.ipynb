# %%
import pandas as pd

# %%
broken_df = pd.read_csv('book_df.csv')

# %%
broken_df
# Out:
#       Book ID (Isbn-13)                                              Title  \
# 0         9780439785969  Harry Potter and the Half-Blood Prince (Harry ...
# 1         9780439358071  Harry Potter and the Order of the Phoenix (Har...
# 2         9780439554893  Harry Potter and the Chamber of Secrets (Harry...
# 3         9780439655484  Harry Potter and the Prisoner of Azkaban (Harr...
# 4         9780439682589  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...                 ...                                                ...
# 11122     9781560254416   Expelled from Eden: A William T. Vollmann Reader
# 11123     9780140110876                        You Bright and Risen Angels
# 11124     9780140131963                    The Ice-Shirt (Seven Dreams #1)
# 11125     9780060878825                                        Poor People
# 11126     9788497646987                        Las aventuras de Tom Sawyer
#
# ...

# %%
problem_list = broken_df['Average Rating'].tolist()
float(problem_list[0]) + 1
# Out:
# 5.57

# %%
for x in range(len(problem_list)):
    try:
        float(problem_list[x]) + 1
    except:
        print(x)
        print(problem_list[x])
        print('bad row')
        broken_df.drop(x, inplace=True)
# Out:
# 3348
#  Jr./Sam B. Warner
# bad row
# 4702
#  one of the founding members of this Tolkien website)/Verlyn Flieger/Turgon (=David E. Smith)
# bad row
# 5877
#  Rawles
# bad row
# 8979
#  Son & Ferguson
# bad row

# %%
fixed_list = broken_df['Average Rating'].tolist()

for x in range(len(fixed_list)):
    try:
        float(fixed_list[x]) + 1
    except:
        print(x)
        print(fixed_list[x])
        print('still busted')

# %%
broken_df
# Out:
#       Book ID (Isbn-13)                                              Title  \
# 0         9780439785969  Harry Potter and the Half-Blood Prince (Harry ...
# 1         9780439358071  Harry Potter and the Order of the Phoenix (Har...
# 2         9780439554893  Harry Potter and the Chamber of Secrets (Harry...
# 3         9780439655484  Harry Potter and the Prisoner of Azkaban (Harr...
# 4         9780439682589  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...                 ...                                                ...
# 11122     9781560254416   Expelled from Eden: A William T. Vollmann Reader
# 11123     9780140110876                        You Bright and Risen Angels
# 11124     9780140131963                    The Ice-Shirt (Seven Dreams #1)
# 11125     9780060878825                                        Poor People
# 11126     9788497646987                        Las aventuras de Tom Sawyer
#
# ...

# %%
broken_df.to_csv('fixed_book_df')
